# %% [markdown]
# <a href="https://colab.research.google.com/github/CakeNuthep/Super_AI/blob/master/Homework/Week2/Question1/22p22c0044_%E0%B8%A8%E0%B8%B8%E0%B8%A0%E0%B8%8A%E0%B8%B1%E0%B8%A2_W2HW1_27092020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
weather = pd.read_csv('https://raw.githubusercontent.com/CakeNuthep/Super_AI/master/Homework/Week2/Question1/Plant_1_Weather_Sensor_Data.csv')
weather
# Out:
#                 DATE_TIME  PLANT_ID  ... MODULE_TEMPERATURE  IRRADIATION
# 0     2020-05-15 00:00:00   4135001  ...          22.857507          0.0
# 1     2020-05-15 00:15:00   4135001  ...          22.761668          0.0
# 2     2020-05-15 00:30:00   4135001  ...          22.592306          0.0
# 3     2020-05-15 00:45:00   4135001  ...          22.360852          0.0
# 4     2020-05-15 01:00:00   4135001  ...          22.165423          0.0
# ...                   ...       ...  ...                ...          ...
# 3177  2020-06-17 22:45:00   4135001  ...          21.480377          0.0
# 3178  2020-06-17 23:00:00   4135001  ...          21.389024          0.0
# 3179  2020-06-17 23:15:00   4135001  ...          20.709211          0.0
# 3180  2020-06-17 23:30:00   4135001  ...          20.734963          0.0
# 3181  2020-06-17 23:45:00   4135001  ...          20.427972          0.0
#
# [3182 rows x 6 columns]

# %%
generation = pd.read_csv("https://raw.githubusercontent.com/CakeNuthep/Super_AI/master/Homework/Week2/Question1/Plant_1_Generation_Data.csv",sep=',',error_bad_lines=False)
generation
# Out:
#               DATE_TIME  PLANT_ID  ... DAILY_YIELD  TOTAL_YIELD
# 0      15-05-2020 00:00   4135001  ...       0.000    6259559.0
# 1      15-05-2020 00:00   4135001  ...       0.000    6183645.0
# 2      15-05-2020 00:00   4135001  ...       0.000    6987759.0
# 3      15-05-2020 00:00   4135001  ...       0.000    7602960.0
# 4      15-05-2020 00:00   4135001  ...       0.000    7158964.0
# ...                 ...       ...  ...         ...          ...
# 68773  17-06-2020 23:45   4135001  ...    5967.000    7287002.0
# 68774  17-06-2020 23:45   4135001  ...    5147.625    7028601.0
# 68775  17-06-2020 23:45   4135001  ...    5819.000    7251204.0
# 68776  17-06-2020 23:45   4135001  ...    5817.000    6583369.0
# 68777  17-06-2020 23:45   4135001  ...    5910.000    7363272.0
#
# [68778 rows x 7 columns]

# %% [markdown]
# # Clean Data

# %%
generation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68778 entries, 0 to 68777
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE_TIME    68778 non-null  object
#  1   PLANT_ID     68778 non-null  int64
#  2   SOURCE_KEY   68778 non-null  object
#  3   DC_POWER     68778 non-null  float64
#  4   AC_POWER     68778 non-null  float64
#  5   DAILY_YIELD  68778 non-null  float64
#  6   TOTAL_YIELD  68778 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 3.7+ MB

# %%
datetimeCorrect = generation.DATE_TIME.str.contains('^[0-9]*-[0-9]*-[0-9]* [0-9]*:[0-9]*$', regex=True)
generation = generation[datetimeCorrect == True]

# %%
datetimeCorrect
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 68773    True
# 68774    True
# 68775    True
# 68776    True
# 68777    True
# Name: DATE_TIME, Length: 68778, dtype: bool

# %%
generation['DATE_TIME'] = pd.to_datetime(generation['DATE_TIME'], format='%d-%m-%Y %H:%M')

# %%
generation
# Out:
#                 DATE_TIME  PLANT_ID  ... DAILY_YIELD  TOTAL_YIELD
# 0     2020-05-15 00:00:00   4135001  ...       0.000    6259559.0
# 1     2020-05-15 00:00:00   4135001  ...       0.000    6183645.0
# 2     2020-05-15 00:00:00   4135001  ...       0.000    6987759.0
# 3     2020-05-15 00:00:00   4135001  ...       0.000    7602960.0
# 4     2020-05-15 00:00:00   4135001  ...       0.000    7158964.0
# ...                   ...       ...  ...         ...          ...
# 68773 2020-06-17 23:45:00   4135001  ...    5967.000    7287002.0
# 68774 2020-06-17 23:45:00   4135001  ...    5147.625    7028601.0
# 68775 2020-06-17 23:45:00   4135001  ...    5819.000    7251204.0
# 68776 2020-06-17 23:45:00   4135001  ...    5817.000    6583369.0
# 68777 2020-06-17 23:45:00   4135001  ...    5910.000    7363272.0
#
# [68778 rows x 7 columns]

# %%
generation.isna().sum()
# Out:
# DATE_TIME      0
# PLANT_ID       0
# SOURCE_KEY     0
# DC_POWER       0
# AC_POWER       0
# DAILY_YIELD    0
# TOTAL_YIELD    0
# dtype: int64

# %%
generation.PLANT_ID.unique()
# Out:
# array([4135001])

# %%
generation.SOURCE_KEY.unique()
# Out:
# array(['1BY6WEcLGh8j5v7', '1IF53ai7Xc0U56Y', '3PZuoBAID5Wc2HD',
#        '7JYdWkrLSPkdwr4', 'McdE0feGgRqW7Ca', 'VHMLBKoKgIrUVDU',
#        'WRmjgnKYAwPKWDb', 'ZnxXDlPa8U1GXgE', 'ZoEaEvLYb1n2sOq',
#        'adLQvlD726eNBSB', 'bvBOhCH3iADSZry', 'iCRJl6heRkivqQ3',
#        'ih0vzX44oOqAx2f', 'pkci93gMrogZuBj', 'rGa61gmuvPhdLxV',
#        'sjndEbLyjtCKgGv', 'uHbuxQJl8lW7ozc', 'wCURE6d3bPkepu2',
#        'z9Y9gH1T5YWrNuG', 'zBIq5rxdHJRwDNY', 'zVJPv84UY57bAof',
#        'YxYtjZvoooNbGkE'], dtype=object)

# %%
weather.head()
# Out:
#              DATE_TIME  PLANT_ID  ... MODULE_TEMPERATURE  IRRADIATION
# 0  2020-05-15 00:00:00   4135001  ...          22.857507          0.0
# 1  2020-05-15 00:15:00   4135001  ...          22.761668          0.0
# 2  2020-05-15 00:30:00   4135001  ...          22.592306          0.0
# 3  2020-05-15 00:45:00   4135001  ...          22.360852          0.0
# 4  2020-05-15 01:00:00   4135001  ...          22.165423          0.0
#
# [5 rows x 6 columns]

# %%
weather.isna().sum()
# Out:
# DATE_TIME              0
# PLANT_ID               0
# SOURCE_KEY             0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# IRRADIATION            0
# dtype: int64

# %%
weather.describe()
# Out:
#         PLANT_ID  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# count     3182.0          3182.000000         3182.000000  3182.000000
# mean   4135001.0            25.531606           31.091015     0.228313
# std          0.0             3.354856           12.261222     0.300836
# min    4135001.0            20.398505           18.140415     0.000000
# 25%    4135001.0            22.705182           21.090553     0.000000
# 50%    4135001.0            24.613814           24.618060     0.024653
# 75%    4135001.0            27.920532           41.307840     0.449588
# max    4135001.0            35.252486           65.545714     1.221652

# %%
weather.PLANT_ID.unique()
# Out:
# array([4135001])

# %%
weather.SOURCE_KEY.unique()
# Out:
# array(['HmiyD2TTLFNqkNe'], dtype=object)

# %%
weather['DATE_TIME'] = pd.to_datetime(weather['DATE_TIME'])

# %%
len(weather.DATE_TIME.unique())
# Out:
# 3182

# %%
len(generation.DATE_TIME.unique())
# Out:
# 3158

# %%
print(len(generation))
# Out:
# 68778

# %%
merg_data = pd.merge(generation, weather, on='DATE_TIME')
merg_data
# Out:
#                 DATE_TIME  PLANT_ID_x  ... MODULE_TEMPERATURE  IRRADIATION
# 0     2020-05-15 00:00:00     4135001  ...          22.857507          0.0
# 1     2020-05-15 00:00:00     4135001  ...          22.857507          0.0
# 2     2020-05-15 00:00:00     4135001  ...          22.857507          0.0
# 3     2020-05-15 00:00:00     4135001  ...          22.857507          0.0
# 4     2020-05-15 00:00:00     4135001  ...          22.857507          0.0
# ...                   ...         ...  ...                ...          ...
# 68769 2020-06-17 23:45:00     4135001  ...          20.427972          0.0
# 68770 2020-06-17 23:45:00     4135001  ...          20.427972          0.0
# 68771 2020-06-17 23:45:00     4135001  ...          20.427972          0.0
# 68772 2020-06-17 23:45:00     4135001  ...          20.427972          0.0
# 68773 2020-06-17 23:45:00     4135001  ...          20.427972          0.0
#
# [68774 rows x 12 columns]

# %%
merg_data.describe()
# Out:
#        PLANT_ID_x      DC_POWER  ...  MODULE_TEMPERATURE   IRRADIATION
# count     68774.0  68774.000000  ...        68774.000000  68774.000000
# mean    4135001.0   3147.177450  ...           31.244997      0.232305
# std           0.0   4036.441826  ...           12.308283      0.301948
# min     4135001.0      0.000000  ...           18.140415      0.000000
# 25%     4135001.0      0.000000  ...           21.123944      0.000000
# 50%     4135001.0    428.571429  ...           24.818984      0.031620
# 75%     4135001.0   6365.468750  ...           41.693659      0.454880
# max     4135001.0  14471.125000  ...           65.545714      1.221652
#
# [8 rows x 9 columns]

# %%
merg_data.isna().sum()
# Out:
# DATE_TIME              0
# PLANT_ID_x             0
# SOURCE_KEY_x           0
# DC_POWER               0
# AC_POWER               0
# DAILY_YIELD            0
# TOTAL_YIELD            0
# PLANT_ID_y             0
# SOURCE_KEY_y           0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# IRRADIATION            0
# dtype: int64

# %%
merg_data = merg_data.drop(['PLANT_ID_x','PLANT_ID_y','SOURCE_KEY_y'],axis=1)

# %%
merg_data
# Out:
#                 DATE_TIME     SOURCE_KEY_x  ...  MODULE_TEMPERATURE  IRRADIATION
# 0     2020-05-15 00:00:00  1BY6WEcLGh8j5v7  ...           22.857507          0.0
# 1     2020-05-15 00:00:00  1IF53ai7Xc0U56Y  ...           22.857507          0.0
# 2     2020-05-15 00:00:00  3PZuoBAID5Wc2HD  ...           22.857507          0.0
# 3     2020-05-15 00:00:00  7JYdWkrLSPkdwr4  ...           22.857507          0.0
# 4     2020-05-15 00:00:00  McdE0feGgRqW7Ca  ...           22.857507          0.0
# ...                   ...              ...  ...                 ...          ...
# 68769 2020-06-17 23:45:00  uHbuxQJl8lW7ozc  ...           20.427972          0.0
# 68770 2020-06-17 23:45:00  wCURE6d3bPkepu2  ...           20.427972          0.0
# 68771 2020-06-17 23:45:00  z9Y9gH1T5YWrNuG  ...           20.427972          0.0
# 68772 2020-06-17 23:45:00  zBIq5rxdHJRwDNY  ...           20.427972          0.0
# 68773 2020-06-17 23:45:00  zVJPv84UY57bAof  ...           20.427972          0.0
#
# [68774 rows x 9 columns]

# %%
data_clean = merg_data.rename(columns = { 'SOURCE_KEY_x': 'SOURCE_KEY'}, inplace = False)

# %%
data_clean
# Out:
#                 DATE_TIME       SOURCE_KEY  ...  MODULE_TEMPERATURE  IRRADIATION
# 0     2020-05-15 00:00:00  1BY6WEcLGh8j5v7  ...           22.857507          0.0
# 1     2020-05-15 00:00:00  1IF53ai7Xc0U56Y  ...           22.857507          0.0
# 2     2020-05-15 00:00:00  3PZuoBAID5Wc2HD  ...           22.857507          0.0
# 3     2020-05-15 00:00:00  7JYdWkrLSPkdwr4  ...           22.857507          0.0
# 4     2020-05-15 00:00:00  McdE0feGgRqW7Ca  ...           22.857507          0.0
# ...                   ...              ...  ...                 ...          ...
# 68769 2020-06-17 23:45:00  uHbuxQJl8lW7ozc  ...           20.427972          0.0
# 68770 2020-06-17 23:45:00  wCURE6d3bPkepu2  ...           20.427972          0.0
# 68771 2020-06-17 23:45:00  z9Y9gH1T5YWrNuG  ...           20.427972          0.0
# 68772 2020-06-17 23:45:00  zBIq5rxdHJRwDNY  ...           20.427972          0.0
# 68773 2020-06-17 23:45:00  zVJPv84UY57bAof  ...           20.427972          0.0
#
# [68774 rows x 9 columns]

# %% [markdown]
# # Analysis

# %%
print(f'min datetime: {data_clean.DATE_TIME.min()}')
print(f'max datetime: {data_clean.DATE_TIME.max()}')
# Out:
# min datetime: 2020-05-15 00:00:00
# max datetime: 2020-06-17 23:45:00

# %%
data_clean['SOURCE_KEY'].hist()
plt.suptitle('number use solar cell')
plt.xticks(rotation=45)
plt.show()

# %%
source_key = data_clean[['SOURCE_KEY','TOTAL_YIELD']].groupby("SOURCE_KEY").mean()
source_key
# Out:
#                   TOTAL_YIELD
# SOURCE_KEY
# 1BY6WEcLGh8j5v7  6.377464e+06
# 1IF53ai7Xc0U56Y  6.313081e+06
# 3PZuoBAID5Wc2HD  7.117013e+06
# 7JYdWkrLSPkdwr4  7.728914e+06
# McdE0feGgRqW7Ca  7.287580e+06
# VHMLBKoKgIrUVDU  7.335465e+06
# WRmjgnKYAwPKWDb  7.155458e+06
# YxYtjZvoooNbGkE  7.307357e+06
# ZnxXDlPa8U1GXgE  6.650663e+06
# ZoEaEvLYb1n2sOq  7.223575e+06
# adLQvlD726eNBSB  6.402446e+06
# bvBOhCH3iADSZry  6.432819e+06
# iCRJl6heRkivqQ3  7.305670e+06
# ih0vzX44oOqAx2f  6.309606e+06
# pkci93gMrogZuBj  7.295685e+06
# rGa61gmuvPhdLxV  7.237456e+06
# sjndEbLyjtCKgGv  7.143000e+06
# uHbuxQJl8lW7ozc  7.166283e+06
# wCURE6d3bPkepu2  6.909712e+06
# z9Y9gH1T5YWrNuG  7.133922e+06
# zBIq5rxdHJRwDNY  6.464955e+06
# zVJPv84UY57bAof  7.243085e+06

# %%
source_key.plot.bar()

# %%
plt.plot(data_clean['DATE_TIME'],data_clean['TOTAL_YIELD'])
plt.gcf().autofmt_xdate()

plt.show()

# %%
solar_cell = data_clean['SOURCE_KEY'].unique()
plt.figure(figsize=(10,10))
for t in solar_cell:
  cell = (data_clean['SOURCE_KEY'] == t)
  df_cell = data_clean[cell]
  plt.plot(df_cell['DATE_TIME'],df_cell['TOTAL_YIELD'])
plt.legend(solar_cell)
plt.xticks(rotation=45)

plt.show()

# %%
solar_cell = data_clean['SOURCE_KEY'].unique()
plt.figure(figsize=(10,10))
for t in solar_cell:
  cell = (data_clean['SOURCE_KEY'] == t)
  df_cell = data_clean[cell]
  plt.plot(df_cell['DATE_TIME'],df_cell['DAILY_YIELD'])
plt.legend(solar_cell)
plt.xticks(rotation=45)

plt.show()

# %%
sns.pairplot(data_clean,hue='SOURCE_KEY',vars=['DAILY_YIELD','AMBIENT_TEMPERATURE','MODULE_TEMPERATURE','IRRADIATION'])

# %%
window_past = 3
before_date = 3
data = data_clean.copy()
data_result = data.copy()
date = data_clean['DATE_TIME']
date = date + np.timedelta64(before_date,'D')
for t in range(window_past):
    date = date + np.timedelta64(1,'D')
    p = data.copy()
    p['DATE_TIME'] = date
    data_result = pd.merge(data_result,p, on=["DATE_TIME", "SOURCE_KEY"], how="left",suffixes=("",f"_past{t}"))
    data = p
data_result.tail()
# Out:
#                 DATE_TIME  ... IRRADIATION_past2
# 68769 2020-06-17 23:45:00  ...               0.0
# 68770 2020-06-17 23:45:00  ...               0.0
# 68771 2020-06-17 23:45:00  ...               0.0
# 68772 2020-06-17 23:45:00  ...               0.0
# 68773 2020-06-17 23:45:00  ...               0.0
#
# [5 rows x 30 columns]

# %%
data_result.isna().sum()
# Out:
# DATE_TIME                        0
# SOURCE_KEY                       0
# DC_POWER                         0
# AC_POWER                         0
# DAILY_YIELD                      0
# TOTAL_YIELD                      0
# AMBIENT_TEMPERATURE              0
# MODULE_TEMPERATURE               0
# IRRADIATION                      0
# DC_POWER_past0               10942
# AC_POWER_past0               10942
# DAILY_YIELD_past0            10942
# TOTAL_YIELD_past0            10942
# AMBIENT_TEMPERATURE_past0    10942
# MODULE_TEMPERATURE_past0     10942
# IRRADIATION_past0            10942
# DC_POWER_past1               12809
# AC_POWER_past1               12809
# DAILY_YIELD_past1            12809
# TOTAL_YIELD_past1            12809
# AMBIENT_TEMPERATURE_past1    12809
# MODULE_TEMPERATURE_past1     12809
# IRRADIATION_past1            12809
# DC_POWER_past2               14555
# AC_POWER_past2               14555
# DAILY_YIELD_past2            14555
# TOTAL_YIELD_past2            14555
# AMBIENT_TEMPERATURE_past2    14555
# MODULE_TEMPERATURE_past2     14555
# IRRADIATION_past2            14555
# dtype: int64

# %%
data_result.dropna(axis=0,inplace=True)

# %%
data_result.isna().sum()
# Out:
# DATE_TIME                    0
# SOURCE_KEY                   0
# DC_POWER                     0
# AC_POWER                     0
# DAILY_YIELD                  0
# TOTAL_YIELD                  0
# AMBIENT_TEMPERATURE          0
# MODULE_TEMPERATURE           0
# IRRADIATION                  0
# DC_POWER_past0               0
# AC_POWER_past0               0
# DAILY_YIELD_past0            0
# TOTAL_YIELD_past0            0
# AMBIENT_TEMPERATURE_past0    0
# MODULE_TEMPERATURE_past0     0
# IRRADIATION_past0            0
# DC_POWER_past1               0
# AC_POWER_past1               0
# DAILY_YIELD_past1            0
# TOTAL_YIELD_past1            0
# AMBIENT_TEMPERATURE_past1    0
# MODULE_TEMPERATURE_past1     0
# IRRADIATION_past1            0
# DC_POWER_past2               0
# AC_POWER_past2               0
# DAILY_YIELD_past2            0
# TOTAL_YIELD_past2            0
# AMBIENT_TEMPERATURE_past2    0
# MODULE_TEMPERATURE_past2     0
# IRRADIATION_past2            0
# dtype: int64

# %%
data_result
# Out:
#                 DATE_TIME  ... IRRADIATION_past2
# 11774 2020-05-21 07:45:00  ...          0.144793
# 11775 2020-05-21 07:45:00  ...          0.144793
# 11776 2020-05-21 07:45:00  ...          0.144793
# 11777 2020-05-21 07:45:00  ...          0.144793
# 11778 2020-05-21 07:45:00  ...          0.144793
# ...                   ...  ...               ...
# 68769 2020-06-17 23:45:00  ...          0.000000
# 68770 2020-06-17 23:45:00  ...          0.000000
# 68771 2020-06-17 23:45:00  ...          0.000000
# 68772 2020-06-17 23:45:00  ...          0.000000
# 68773 2020-06-17 23:45:00  ...          0.000000
#
# [49443 rows x 30 columns]

# %%
df_one_hot = pd.get_dummies(data_result.SOURCE_KEY, prefix='source')
df_one_hot
# Out:
#        source_1BY6WEcLGh8j5v7  ...  source_zVJPv84UY57bAof
# 11774                       1  ...                       0
# 11775                       0  ...                       0
# 11776                       0  ...                       0
# 11777                       0  ...                       0
# 11778                       0  ...                       0
# ...                       ...  ...                     ...
# 68769                       0  ...                       0
# 68770                       0  ...                       0
# 68771                       0  ...                       0
# 68772                       0  ...                       0
# 68773                       0  ...                       1
#
# [49443 rows x 22 columns]

# %%
data_process = pd.concat([data_result,df_one_hot], axis=1)

# %%
data_process
# Out:
#                 DATE_TIME  ... source_zVJPv84UY57bAof
# 11774 2020-05-21 07:45:00  ...                      0
# 11775 2020-05-21 07:45:00  ...                      0
# 11776 2020-05-21 07:45:00  ...                      0
# 11777 2020-05-21 07:45:00  ...                      0
# 11778 2020-05-21 07:45:00  ...                      0
# ...                   ...  ...                    ...
# 68769 2020-06-17 23:45:00  ...                      0
# 68770 2020-06-17 23:45:00  ...                      0
# 68771 2020-06-17 23:45:00  ...                      0
# 68772 2020-06-17 23:45:00  ...                      0
# 68773 2020-06-17 23:45:00  ...                      1
#
# [49443 rows x 52 columns]

# %%
data_process = data_process.drop(['SOURCE_KEY'],axis=1)

# %%
data_process
# Out:
#                 DATE_TIME  ...  source_zVJPv84UY57bAof
# 11774 2020-05-21 07:45:00  ...                       0
# 11775 2020-05-21 07:45:00  ...                       0
# 11776 2020-05-21 07:45:00  ...                       0
# 11777 2020-05-21 07:45:00  ...                       0
# 11778 2020-05-21 07:45:00  ...                       0
# ...                   ...  ...                     ...
# 68769 2020-06-17 23:45:00  ...                       0
# 68770 2020-06-17 23:45:00  ...                       0
# 68771 2020-06-17 23:45:00  ...                       0
# 68772 2020-06-17 23:45:00  ...                       0
# 68773 2020-06-17 23:45:00  ...                       1
#
# [49443 rows x 51 columns]

# %%
data_process = data_process.reset_index(drop=True)
y_data = data_process['TOTAL_YIELD']
y_data
# Out:
# 0        6298642.25
# 1        6225770.20
# 2        7029836.20
# 3        7644308.80
# 4        7201377.60
#             ...
# 49438    7287002.00
# 49439    7028601.00
# 49440    7251204.00
# 49441    6583369.00
# 49442    7363272.00
# Name: TOTAL_YIELD, Length: 49443, dtype: float64

# %% [markdown]
# # Train

# %%
x_data = data_process.drop(['DATE_TIME','TOTAL_YIELD','TOTAL_YIELD_past0','TOTAL_YIELD_past1','TOTAL_YIELD_past2'],axis = 1)

# %%
x_data
# Out:
#        DC_POWER  AC_POWER  ...  source_zBIq5rxdHJRwDNY  source_zVJPv84UY57bAof
# 0       3946.25   387.775  ...                       0                       0
# 1       3553.40   348.880  ...                       0                       0
# 2       3534.60   347.020  ...                       0                       0
# 3       3403.80   334.280  ...                       0                       0
# 4       3339.80   328.120  ...                       0                       0
# ...         ...       ...  ...                     ...                     ...
# 49438      0.00     0.000  ...                       0                       0
# 49439      0.00     0.000  ...                       0                       0
# 49440      0.00     0.000  ...                       0                       0
# 49441      0.00     0.000  ...                       1                       0
# 49442      0.00     0.000  ...                       0                       1
#
# [49443 rows x 46 columns]

# %%
# normalize
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
x = x_data.values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
x_normalize = pd.DataFrame(x_scaled,columns=x_data.columns)

# %%
x_normalize.loc[:,:]
# Out:
#        DC_POWER  AC_POWER  ...  source_zBIq5rxdHJRwDNY  source_zVJPv84UY57bAof
# 0      0.272698  0.274833  ...                     0.0                     0.0
# 1      0.245551  0.247266  ...                     0.0                     0.0
# 2      0.244252  0.245948  ...                     0.0                     0.0
# 3      0.235213  0.236918  ...                     0.0                     0.0
# 4      0.230791  0.232553  ...                     0.0                     0.0
# ...         ...       ...  ...                     ...                     ...
# 49438  0.000000  0.000000  ...                     0.0                     0.0
# 49439  0.000000  0.000000  ...                     0.0                     0.0
# 49440  0.000000  0.000000  ...                     0.0                     0.0
# 49441  0.000000  0.000000  ...                     1.0                     0.0
# 49442  0.000000  0.000000  ...                     0.0                     1.0
#
# [49443 rows x 46 columns]

# %%
len(x_normalize.columns)
# Out:
# 46

# %%
len(y_data)
# Out:
# 49443

# %%
len(x_data)
# Out:
# 49443

# %%
def get_ten_Fold():
  k = 10
  list_fold_input = []
  list_fold_label = []
  for i in range(k):
    list_fold_input.append([])
    list_fold_label.append([])
  
  for i,row in x_normalize.iterrows():
    index_list_fold = i % k
    #print(index_list_fold)
    list_fold_input[index_list_fold].append(np.array(x_data.loc[i,:]))
    list_fold_label[index_list_fold].append(np.array(y_data.loc[i]))
  return (list_fold_input,list_fold_label)

# %%
list_fold_input,list_fold_label = get_ten_Fold()

# %%
k = 10
for i in range(len(list_fold_input)):
  print(f"k={i}")
  print(f"input: {np.array(list_fold_input[i]).shape}")
  print(f"label: {np.array(list_fold_label[i]).shape}")
  print()
# Out:
# k=0
# input: (4945, 46)
# label: (4945,)
#
# k=1
# input: (4945, 46)
# label: (4945,)
#
# k=2
# input: (4945, 46)
# label: (4945,)
#
# k=3
# input: (4944, 46)
# label: (4944,)
#
# k=4
# input: (4944, 46)
# label: (4944,)
#
# k=5
# input: (4944, 46)
# label: (4944,)
#
# k=6
# input: (4944, 46)
# label: (4944,)
#
# k=7
# input: (4944, 46)
# label: (4944,)
#
# k=8
# input: (4944, 46)
# label: (4944,)
#
# k=9
# input: (4944, 46)
# label: (4944,)

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn import metrics
import xgboost as xgb
import time

# %%
def get_ten_Fold(x_data,y_data):
  k = 10
  list_fold_input = []
  list_fold_label = []
  for i in range(k):
    list_fold_input.append([])
    list_fold_label.append([])
  
  for i,row in x_normalize.iterrows():
    index_list_fold = i % k
    #print(index_list_fold)
    list_fold_input[index_list_fold].append(np.array(x_data.loc[i,:]))
    list_fold_label[index_list_fold].append(np.array(y_data.loc[i]))
  return (list_fold_input,list_fold_label)

def getData(before_date,window_past = 3):
  data = data_clean.copy()
  data_result = data.copy()
  date = data_clean['DATE_TIME']
  date = date + np.timedelta64(before_date,'D')
  for t in range(window_past):
      date = date + np.timedelta64(1,'D')
      p = data.copy()
      p['DATE_TIME'] = date
      data_result = pd.merge(data_result,p, on=["DATE_TIME", "SOURCE_KEY"], how="left",suffixes=("",f"_past{t}"))
      data = p
  data_result.tail()
  data_result.dropna(axis=0,inplace=True)
  df_one_hot = pd.get_dummies(data_result.SOURCE_KEY, prefix='source')
  data_process = pd.concat([data_result,df_one_hot], axis=1)
  data_process = data_process.drop(['SOURCE_KEY'],axis=1)
  data_process = data_process.reset_index(drop=True)
  return data_process

def evaluate(model,x_test,y_test):
  pred = model.predict(x_test)
  rmse = np.sqrt(metrics.mean_squared_error(y_test, pred))
  print(f'Root Mean Squared Error (RMSE): {rmse}')

  r2 = model.score(x_test, y_test)
  print(f'R2 : {r2}')
  return (rmse,r2)

def train(list_fold_input,list_fold_label,model):
  list_rmse = []
  list_r2 = []
  for index_test in range(len(list_fold_input)):
    start_train_time = time.time()
    for index_train,train_data in enumerate(list_fold_input):
      if index_train == index_test:
        continue
      x_train = np.array(list_fold_input[index_train])
      y_train = np.array(list_fold_label[index_train])
      model.fit(x_train,y_train)
    end_train_time = time.time()
    x_test = np.array(list_fold_input[index_test])
    y_test = np.array(list_fold_label[index_test])
    print(f"Fold #{index_test+1}---------------------------------------")
    rmse,r2 = evaluate(model,x_test,y_test)
    list_rmse.append(rmse)
    list_r2.append(r2)
  print('++++++ Average +++++++')
  rmse = np.mean(list_rmse)
  r2 = np.mean(list_r2)
  print(f'Average Root Mean Squared Error (RMSE): {rmse}')
  print(f'Average R2: {r2}')
  return (rmse,r2)

# %%
list_sum = []

# %%
#ใช้ข้อมูลของวันก่อนหน้า 3 วันก่อนหน้า เพื่อทําการคาคคะเนค่า Yield (TOTAL_YIELD) โดยใช้ข้อมูลคอลัมน์อื่นที่ไม่ใช้ TOTAL_YIELD เป็น Input มาทํานาย

data_process = getData(3,3)
x_data = data_process.drop(['DATE_TIME','DC_POWER',	'AC_POWER',	'DAILY_YIELD',	'AMBIENT_TEMPERATURE',	'MODULE_TEMPERATURE'	,'IRRADIATION','TOTAL_YIELD','TOTAL_YIELD_past0','TOTAL_YIELD_past1','TOTAL_YIELD_past2'],axis = 1)
min_max_scaler = preprocessing.MinMaxScaler()
x = x_data.values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
x_normalize = pd.DataFrame(x_scaled,columns=x_data.columns)
y_data = data_process['TOTAL_YIELD']

list_fold_input, list_fold_label = get_ten_Fold(x_normalize,y_data)

linear_regression = LinearRegression()
ridge = Ridge()
lasso = Lasso(tol=1e-2)

print("### process Linear regression ####")
linear_regression_rsme,linear_regression_r2 = train(list_fold_input, list_fold_label,linear_regression)
print()

print("### process Ridge ####")
ridge_rsme,ridge_r2 = train(list_fold_input, list_fold_label,ridge)
print()

print("### process Lasso ####")
lasso_rsme,lasso_r2 = train(list_fold_input, list_fold_label,lasso)
print()

list_sum.append((linear_regression_rsme,ridge_rsme,lasso_rsme))
print()
print()
print("###Sumary###")
print(f"Linear regression:")
print(f"      rmse: {linear_regression_rsme}")
print(f"      r2: {linear_regression_r2}")
print(f"Ridge:")
print(f"      rmse: {ridge_rsme}")
print(f"      r2: {ridge_r2}")
print(f"Lasso:")
print(f"      rmse: {lasso_rsme}")
print(f"      r2: {lasso_r2}")
# Out:
# ### process Linear regression ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 95811.51121371609
# R2 : 0.9497853188387452
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 34123.711397650295
# R2 : 0.9929148887682818
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 95747.17154265005
# R2 : 0.9498885276181686
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 34338.74324233543
# R2 : 0.992782172559479
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 95665.20446180063
# R2 : 0.9496620448213735
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 34658.980914858876
# R2 : 0.9925138059201868
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 95630.06007131816
# R2 : 0.9497581604179367
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 34681.959353527425
# R2 : 0.9925415791559847
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 95709.92402710508
# R2 : 0.9498454111822237
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 95345.5771284821
# R2 : 0.9443080959019873
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 71171.28433534442
# Average R2: 0.9664000005184368
#
# ### process Ridge ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 95762.41161734695
# R2 : 0.9498367717133503
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 34221.77741365765
# R2 : 0.9928741073299996
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 95781.19021971003
# R2 : 0.9498529123867117
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 34439.65328516593
# R2 : 0.9927396886828265
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 95700.26919770848
# R2 : 0.9496251367188226
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 34733.58203698462
# R2 : 0.9924815441797834
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 95636.8619795275
# R2 : 0.9497510130307157
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 34750.47491656165
# R2 : 0.9925120812452033
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 95638.75322059989
# R2 : 0.9499199743040637
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 94732.15761508487
# R2 : 0.9450223944998101
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 71139.71315023475
# Average R2: 0.9664615624091288
#
# ### process Lasso ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 94921.07765271366
# R2 : 0.9507143317570158
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 34519.33896792344
# R2 : 0.9927496479733326
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 94966.36407513017
# R2 : 0.9507025019922241
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 34703.175868502316
# R2 : 0.9926281558617617
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 94914.81794216389
# R2 : 0.950448637606899
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 34980.52505280474
# R2 : 0.9923742572243559
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 94798.25095869692
# R2 : 0.9506283860372438
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 35020.44927442976
# R2 : 0.9923952829166868
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 94837.14943422028
# R2 : 0.9507559555438482
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 93168.9595005686
# R2 : 0.9468218219754142
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 70683.01087271537
# Average R2: 0.9670218978888782
#
#
#
# ###Sumary###
# Linear regression:
#       rmse: 71171.28433534442
#       r2: 0.9664000005184368
# Ridge:
#       rmse: 71139.71315023475
#       r2: 0.9664615624091288
# Lasso:
#       rmse: 70683.01087271537
#       r2: 0.9670218978888782

# %%
#ใช้ข้อมูลของวันก่อนหน้า 3 วันก่อนหน้า เพื่อทําการคาคคะเนค่า Yield (TOTAL_YIELD) โดยใช้ข้อมูลคอลัมน์อื่นที่ไม่
#ใช้ TOTAL_YIELD เป็น Input มาทํานาย
#   o โดยลองทั้งการนําข้อมูลเฉพาะ 3 วันของ 3 วันก่อนหน้าก่อนหน้าทุกคอลัมน์รวมทั้งคอลัมน์TOTAL_YIELD
#     ของ 3 วันนั้น (ดูcomment ข้างล่าง)
x_data = data_process.drop(['DATE_TIME','DC_POWER',	'AC_POWER',	'DAILY_YIELD',	'AMBIENT_TEMPERATURE',	'MODULE_TEMPERATURE'	,'IRRADIATION','TOTAL_YIELD'],axis = 1)
min_max_scaler = preprocessing.MinMaxScaler()
x = x_data.values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
x_normalize = pd.DataFrame(x_scaled,columns=x_data.columns)
y_data = data_process['TOTAL_YIELD']

list_fold_input, list_fold_label = get_ten_Fold(x_normalize,y_data)

linear_regression = LinearRegression()
ridge = Ridge()
lasso = Lasso(tol=1e-2)

print("### process Linear regression ####")
linear_regression_rsme,linear_regression_r2 = train(list_fold_input, list_fold_label,linear_regression)
print()

print("### process Ridge ####")
ridge_rsme,ridge_r2 = train(list_fold_input, list_fold_label,ridge)
print()

print("### process Lasso ####")
lasso_rsme,lasso_r2 = train(list_fold_input, list_fold_label,lasso)
print()

list_sum.append((linear_regression_rsme,ridge_rsme,lasso_rsme))
print()
print()
print("###Sumary###")
print(f"Linear regression:")
print(f"      rmse: {linear_regression_rsme}")
print(f"      r2: {linear_regression_r2}")
print(f"Ridge:")
print(f"      rmse: {ridge_rsme}")
print(f"      r2: {ridge_r2}")
print(f"Lasso:")
print(f"      rmse: {lasso_rsme}")
print(f"      r2: {lasso_r2}")
# Out:
# ### process Linear regression ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 1923.758715957159
# R2 : 0.999979755990615
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 1384.0839695704608
# R2 : 0.9999883437452712
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 1921.8659407946154
# R2 : 0.9999798102269438
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 1389.115037569403
# R2 : 0.9999881882532333
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 1919.2972479925277
# R2 : 0.9999797384790579
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 1385.1057087045706
# R2 : 0.9999880437402198
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 1919.0156352277886
# R2 : 0.9999797682382687
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 1386.460462782088
# R2 : 0.999988080593972
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 1923.3954274582213
# R2 : 0.9999797449234058
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 1861.4213862009133
# R2 : 0.9999787734036458
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 1701.3519532257749
# Average R2: 0.9999830247594634
#
# ### process Ridge ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 6961.318790090362
# R2 : 0.9997349191381047
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 3037.7483789924663
# R2 : 0.9999438515531047
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 6963.969626676362
# R2 : 0.9997349065524326
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 3031.815705067384
# R2 : 0.9999437343553935
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 6959.580189622998
# R2 : 0.9997335880826838
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 3049.2653265860617
# R2 : 0.9999420544706025
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 6955.716855332053
# R2 : 0.9997341966407567
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 3059.076257491734
# R2 : 0.9999419743195815
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 6953.970667189285
# R2 : 0.9997352338622983
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 6682.828048274481
# R2 : 0.9997264028707108
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 5365.528984532319
# Average R2: 0.9998170861845669
#
# ### process Lasso ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 4614.643965272557
# R2 : 0.9998835145376425
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 3305.9814689010327
# R2 : 0.9999334979578184
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 4590.960470733053
# R2 : 0.9998847894198705
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 3343.843703686895
# R2 : 0.9999315569047964
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 4575.703286203334
# R2 : 0.9998848395718286
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 3336.8139840404942
# R2 : 0.9999306105415603
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 4594.431359880214
# R2 : 0.9998840314543965
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 3302.20198572593
# R2 : 0.9999323844004109
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 4607.423911371437
# R2 : 0.9998837713817065
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 2791.4954045671634
# R2 : 0.9999522619365552
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 3906.349954038211
# Average R2: 0.9999101258106584
#
#
#
# ###Sumary###
# Linear regression:
#       rmse: 1701.3519532257749
#       r2: 0.9999830247594634
# Ridge:
#       rmse: 5365.528984532319
#       r2: 0.9998170861845669
# Lasso:
#       rmse: 3906.349954038211
#       r2: 0.9999101258106584

# %%
#ใช้ข้อมูลของวันก่อนหน้า 3 วันก่อนหน้า เพื่อทําการคาคคะเนค่า Yield (TOTAL_YIELD) โดยใช้ข้อมูลคอลัมน์อื่นที่ไม่
#ใช้ TOTAL_YIELD เป็น Input มาทํานาย
#   o ลองรวมข้อมูลของวันปัจจุบันที่ไม่ใช้คอลัมน์TOTAL_YIELD เข้ากับข้อมูล 3 วัน ของ 7 วันก่อนหน้า

x_data = data_process.drop(['DATE_TIME','TOTAL_YIELD','TOTAL_YIELD_past0','TOTAL_YIELD_past1','TOTAL_YIELD_past2'],axis = 1)
min_max_scaler = preprocessing.MinMaxScaler()
x = x_data.values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
x_normalize = pd.DataFrame(x_scaled,columns=x_data.columns)
y_data = data_process['TOTAL_YIELD']

list_fold_input, list_fold_label = get_ten_Fold(x_normalize,y_data)

linear_regression = LinearRegression()
ridge = Ridge()
lasso = Lasso(tol=1e-2)

print("### process Linear regression ####")
linear_regression_rsme,linear_regression_r2 = train(list_fold_input, list_fold_label,linear_regression)
print()

print("### process Ridge ####")
ridge_rsme,ridge_r2 = train(list_fold_input, list_fold_label,ridge)
print()

print("### process Lasso ####")
lasso_rsme,lasso_r2 = train(list_fold_input, list_fold_label,lasso)
print()

list_sum.append((linear_regression_rsme,ridge_rsme,lasso_rsme))
print()
print()
print("###Sumary###")
print(f"Linear regression:")
print(f"      rmse: {linear_regression_rsme}")
print(f"      r2: {linear_regression_r2}")
print(f"Ridge:")
print(f"      rmse: {ridge_rsme}")
print(f"      r2: {ridge_r2}")
print(f"Lasso:")
print(f"      rmse: {lasso_rsme}")
print(f"      r2: {lasso_r2}")
# Out:
# ### process Linear regression ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 92397.10008984072
# R2 : 0.9533005236329809
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 33030.34570828004
# R2 : 0.9933616462654316
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 92300.563690624
# R2 : 0.9534313162063099
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 33158.78291591581
# R2 : 0.9932696931504308
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 92214.525407543
# R2 : 0.9532279686039153
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 33450.41243963755
# R2 : 0.9930267945957785
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 92187.58481488962
# R2 : 0.953310249862704
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 33415.70503752917
# R2 : 0.993076257741574
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 92221.24309817371
# R2 : 0.9534350999270654
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 91614.93312996085
# R2 : 0.9485810148555209
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 68599.11963323943
# Average R2: 0.9688020564841711
#
# ### process Ridge ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 92505.82536209117
# R2 : 0.9531905548002533
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 33134.97540554436
# R2 : 0.9933195232410355
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 92504.49744790157
# R2 : 0.9532253062366217
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 33277.39409646806
# R2 : 0.9932214575194303
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 92426.67550402822
# R2 : 0.9530125121977983
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 33545.750397536045
# R2 : 0.9929869888945537
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 92378.09211448068
# R2 : 0.953117080059997
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 33510.51187553224
# R2 : 0.9930369140076803
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 92327.80266341333
# R2 : 0.9533274283745542
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 91140.54360408241
# R2 : 0.9491121395019814
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 68675.20684710781
# Average R2: 0.9687549904833904
#
# ### process Lasso ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 93364.62712952233
# R2 : 0.9523173851847773
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 33687.44004853726
# R2 : 0.9930948968335025
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 93389.52515993311
# R2 : 0.9523260001111378
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 33792.31790836687
# R2 : 0.9930100564795812
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 93350.54818723765
# R2 : 0.9520684683720393
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 34046.82097545386
# R2 : 0.9927759184742839
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 93248.44560633397
# R2 : 0.9522294900291024
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 34088.24966556022
# R2 : 0.9927947502481316
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 93245.72457448338
# R2 : 0.9523947788126182
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 90694.67942915332
# R2 : 0.9496088136491386
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 69290.8378684582
# Average R2: 0.9682620558194314
#
#
#
# ###Sumary###
# Linear regression:
#       rmse: 68599.11963323943
#       r2: 0.9688020564841711
# Ridge:
#       rmse: 68675.20684710781
#       r2: 0.9687549904833904
# Lasso:
#       rmse: 69290.8378684582
#       r2: 0.9682620558194314

# %%
# ใช้ข้อมูลของวันก่อนหน้า 7 วันก่อนหน้า เพื่อทําการคาคคะเนค่า Yield (TOTAL_YIELD) โดยใช้ข้อมูลคอลัมน์อื่นที่ไม่ใช้ TOTAL_YIELD เป็น Input มาทํานาย
data_process = getData(7,3)
x_data = data_process.drop(['DATE_TIME','DC_POWER',	'AC_POWER',	'DAILY_YIELD',	'AMBIENT_TEMPERATURE',	'MODULE_TEMPERATURE'	,'IRRADIATION','TOTAL_YIELD','TOTAL_YIELD_past0','TOTAL_YIELD_past1','TOTAL_YIELD_past2'],axis = 1)
min_max_scaler = preprocessing.MinMaxScaler()
x = x_data.values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
x_normalize = pd.DataFrame(x_scaled,columns=x_data.columns)
y_data = data_process['TOTAL_YIELD']

list_fold_input, list_fold_label = get_ten_Fold(x_normalize,y_data)

linear_regression = LinearRegression()
ridge = Ridge()
lasso = Lasso(tol=1e-2)

print("### process Linear regression ####")
linear_regression_rsme,linear_regression_r2 = train(list_fold_input, list_fold_label,linear_regression)
print()

print("### process Ridge ####")
ridge_rsme,ridge_r2 = train(list_fold_input, list_fold_label,ridge)
print()

print("### process Lasso ####")
lasso_rsme,lasso_r2 = train(list_fold_input, list_fold_label,lasso)
print()

list_sum.append((linear_regression_rsme,ridge_rsme,lasso_rsme))
print()
print()
print("###Sumary###")
print(f"Linear regression:")
print(f"      rmse: {linear_regression_rsme}")
print(f"      r2: {linear_regression_r2}")
print(f"Ridge:")
print(f"      rmse: {ridge_rsme}")
print(f"      r2: {ridge_r2}")
print(f"Lasso:")
print(f"      rmse: {lasso_rsme}")
print(f"      r2: {lasso_r2}")
# Out:
# ### process Linear regression ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 48100.67542261746
# R2 : 0.987762108895374
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 46233.47505166034
# R2 : 0.9863564721119988
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 48079.67132822984
# R2 : 0.9875591280802446
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 46395.86639056025
# R2 : 0.9861999235391558
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 48134.907968297855
# R2 : 0.9875323440411715
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 46460.76658483622
# R2 : 0.9859972205711316
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 48191.28543473685
# R2 : 0.9875386413928888
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 46289.9239808951
# R2 : 0.9860940920080901
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 48178.63410938137
# R2 : 0.9876963984254943
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 48469.29720958277
# R2 : 0.9848644172087082
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 47453.4503480798
# Average R2: 0.9867600746274258
#
# ### process Ridge ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 48721.976044401265
# R2 : 0.9874439214830056
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 46377.87645608835
# R2 : 0.9862711131260771
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 48702.749219930854
# R2 : 0.9872345892547911
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 46345.73025116798
# R2 : 0.9862297326053938
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 48744.011585258384
# R2 : 0.987214813880575
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 46412.69263576376
# R2 : 0.986026183529923
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 48774.55321761592
# R2 : 0.9872351718437734
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 46423.896041955
# R2 : 0.9860134827116716
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 48755.78537847341
# R2 : 0.9873998531829672
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 48677.23689436752
# R2 : 0.9847342713375095
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 47793.650772502246
# Average R2: 0.9865803132955688
#
# ### process Lasso ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 48781.59327679229
# R2 : 0.9874131749210754
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 46413.21075142842
# R2 : 0.9862501856764242
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 48779.71615462861
# R2 : 0.98719420997827
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 46355.68721645978
# R2 : 0.9862238151324273
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 48847.27763001751
# R2 : 0.9871605846907259
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 46421.10415995316
# R2 : 0.9860211180299591
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 48865.85285078588
# R2 : 0.9871873389139961
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 46443.94810432765
# R2 : 0.9860013975955675
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 48826.49464930469
# R2 : 0.9873632793386178
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 48602.103670860735
# R2 : 0.9847813602155471
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 47833.698846455874
# Average R2: 0.9865596464492612
#
#
#
# ###Sumary###
# Linear regression:
#       rmse: 47453.4503480798
#       r2: 0.9867600746274258
# Ridge:
#       rmse: 47793.650772502246
#       r2: 0.9865803132955688
# Lasso:
#       rmse: 47833.698846455874
#       r2: 0.9865596464492612

# %%
# ใช้ข้อมูลของวันก่อนหน้า 7 วันก่อนหน้า เพื่อทําการคาคคะเนค่า Yield (TOTAL_YIELD) โดยใช้ข้อมูลคอลัมน์อื่นที่ไม่ใช้ TOTAL_YIELD เป็น Input มาทํานาย (ดูcomment ข้างล่าง)
#    o โดยลองทั้งการนําข้อมูลเฉพาะ 3 วันของ 7 วันก่อนหน้าทุกคอลัมน์รวมทั้งคอลัมน์TOTAL_YIELD ของ 3 วันนั้น

x_data = data_process.drop(['DATE_TIME','DC_POWER',	'AC_POWER',	'DAILY_YIELD',	'AMBIENT_TEMPERATURE',	'MODULE_TEMPERATURE'	,'IRRADIATION','TOTAL_YIELD'],axis = 1)
min_max_scaler = preprocessing.MinMaxScaler()
x = x_data.values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
x_normalize = pd.DataFrame(x_scaled,columns=x_data.columns)
y_data = data_process['TOTAL_YIELD']

list_fold_input, list_fold_label = get_ten_Fold(x_normalize,y_data)

linear_regression = LinearRegression()
ridge = Ridge()
lasso = Lasso(tol=1e-2)

print("### process Linear regression ####")
linear_regression_rsme,linear_regression_r2 = train(list_fold_input, list_fold_label,linear_regression)
print()

print("### process Ridge ####")
ridge_rsme,ridge_r2 = train(list_fold_input, list_fold_label,ridge)
print()

print("### process Lasso ####")
lasso_rsme,lasso_r2 = train(list_fold_input, list_fold_label,lasso)
print()

list_sum.append((linear_regression_rsme,ridge_rsme,lasso_rsme))
print()
print()
print("###Sumary###")
print(f"Linear regression:")
print(f"      rmse: {linear_regression_rsme}")
print(f"      r2: {linear_regression_r2}")
print(f"Ridge:")
print(f"      rmse: {ridge_rsme}")
print(f"      r2: {ridge_r2}")
print(f"Lasso:")
print(f"      rmse: {lasso_rsme}")
print(f"      r2: {lasso_r2}")
# Out:
# ### process Linear regression ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 1669.920433073473
# R2 : 0.9999852498718841
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 1345.8086892439812
# R2 : 0.9999884394029535
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 1674.9701627376276
# R2 : 0.9999849012154234
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 1342.8854715476355
# R2 : 0.9999884388545498
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 1669.8550191953493
# R2 : 0.9999849954819416
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 1357.7352940172689
# R2 : 0.999988041637328
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 1670.183762118527
# R2 : 0.9999850322373778
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 1351.3118641674282
# R2 : 0.9999881494748593
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 1671.6411425398253
# R2 : 0.9999851881469312
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 1699.687362983828
# R2 : 0.9999813875393015
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 1545.3999201624943
# Average R2: 0.999985982386255
#
# ### process Ridge ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 3252.773803591057
# R2 : 0.9999440355857765
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 2628.2526896752256
# R2 : 0.9999559092138144
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 3254.9571415553182
# R2 : 0.9999429811586881
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 2618.224017162849
# R2 : 0.9999560522627648
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 3253.1210565120255
# R2 : 0.9999430537713699
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 2624.219224343669
# R2 : 0.9999553273484495
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 3256.2006757814497
# R2 : 0.9999431080660699
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 2626.149772929716
# R2 : 0.9999552425435082
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 3254.789768749348
# R2 : 0.9999438474896476
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 3243.5928677455695
# R2 : 0.9999322173761417
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 3001.228101804623
# Average R2: 0.9999471774816231
#
# ### process Lasso ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 4675.867384135673
# R2 : 0.9998843545352956
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 4660.960506484279
# R2 : 0.9998613357669602
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 4672.7438880268055
# R2 : 0.9998824908202303
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 4674.492566402961
# R2 : 0.9998599149267856
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 4659.800890159602
# R2 : 0.9998831579312036
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 4649.275949168565
# R2 : 0.9998597792928975
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 4678.601877717335
# R2 : 0.9998825479626926
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 4633.078573206197
# R2 : 0.9998606953069984
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 4652.009394685513
# R2 : 0.9998852891603938
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 4585.942277381979
# R2 : 0.9998645051243259
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 4654.27733073689
# Average R2: 0.9998724070827784
#
#
#
# ###Sumary###
# Linear regression:
#       rmse: 1545.3999201624943
#       r2: 0.999985982386255
# Ridge:
#       rmse: 3001.228101804623
#       r2: 0.9999471774816231
# Lasso:
#       rmse: 4654.27733073689
#       r2: 0.9998724070827784

# %%
# ใช้ข้อมูลของวันก่อนหน้า 7 วันก่อนหน้า เพื่อทําการคาคคะเนค่า Yield (TOTAL_YIELD) โดยใช้ข้อมูลคอลัมน์อื่นที่ไม่ใช้ TOTAL_YIELD เป็น Input มาทํานาย (ดูcomment ข้างล่าง)
#     o ลองรวมข้อมูลของวันปัจจุบันที่ไม่ใช้คอลัมน์TOTAL_YIELD เข้ากับข้อมูล 3 วัน ของ 7 วันก่อนหน้า

x_data = data_process.drop(['DATE_TIME','TOTAL_YIELD','TOTAL_YIELD_past0','TOTAL_YIELD_past1','TOTAL_YIELD_past2'],axis = 1)
min_max_scaler = preprocessing.MinMaxScaler()
x = x_data.values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
x_normalize = pd.DataFrame(x_scaled,columns=x_data.columns)
y_data = data_process['TOTAL_YIELD']

list_fold_input, list_fold_label = get_ten_Fold(x_normalize,y_data)

linear_regression = LinearRegression()
ridge = Ridge()
lasso = Lasso(tol=1e-2)

print("### process Linear regression ####")
linear_regression_rsme,linear_regression_r2 = train(list_fold_input, list_fold_label,linear_regression)
print()

print("### process Ridge ####")
ridge_rsme,ridge_r2 = train(list_fold_input, list_fold_label,ridge)
print()

print("### process Lasso ####")
lasso_rsme,lasso_r2 = train(list_fold_input, list_fold_label,lasso)
print()

list_sum.append((linear_regression_rsme,ridge_rsme,lasso_rsme))
print()
print()
print("###Sumary###")
print(f"Linear regression:")
print(f"      rmse: {linear_regression_rsme}")
print(f"      r2: {linear_regression_r2}")
print(f"Ridge:")
print(f"      rmse: {ridge_rsme}")
print(f"      r2: {ridge_r2}")
print(f"Lasso:")
print(f"      rmse: {lasso_rsme}")
print(f"      r2: {lasso_r2}")
# Out:
# ### process Linear regression ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 49506.63074712586
# R2 : 0.9870362401734838
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 43475.49621263481
# R2 : 0.9879356840336561
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 49418.496180749105
# R2 : 0.986856625283857
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 43509.88946754877
# R2 : 0.9878633486954608
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 49413.28049371927
# R2 : 0.9868613152492809
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 43588.925994355006
# R2 : 0.9876748037757773
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 49586.25061029817
# R2 : 0.9868067766468215
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 43453.79146087732
# R2 : 0.9877458901821444
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 49549.86647021893
# R2 : 0.9869860759085828
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 50105.52079201387
# R2 : 0.9838252765584011
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 47160.81484295411
# Average R2: 0.9869592036507464
#
# ### process Ridge ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 50409.82800726311
# R2 : 0.9865589045138169
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 43703.25359318503
# R2 : 0.987808948994373
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 50311.059657310514
# R2 : 0.9863775642635128
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 43562.213987058676
# R2 : 0.9878341403336602
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 50288.342405861215
# R2 : 0.9863918477555665
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 43652.83647024834
# R2 : 0.9876386346520233
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 50418.627718948585
# R2 : 0.9863601242316149
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 43661.34484154648
# R2 : 0.9876285491649854
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 50408.44838103696
# R2 : 0.9865311675125406
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 50220.79105861516
# R2 : 0.9837507694262081
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 47663.6746121074
# Average R2: 0.9866880650848302
#
# ### process Lasso ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 49439.29220674754
# R2 : 0.9870714826027972
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 43953.04750966746
# R2 : 0.9876691903737852
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 49385.596982786024
# R2 : 0.986874119242107
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 43891.060089459505
# R2 : 0.987649769726226
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 49406.588624552656
# R2 : 0.9868648736613104
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 43983.48605968935
# R2 : 0.9874506624460079
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 49457.70897759763
# R2 : 0.9868750891467762
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 43999.40988108992
# R2 : 0.9874362258734903
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 49497.01081258944
# R2 : 0.9870138254340461
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 49272.94206456649
# R2 : 0.9843583453874589
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 47228.6143208746
# Average R2: 0.9869263583894006
#
#
#
# ###Sumary###
# Linear regression:
#       rmse: 47160.81484295411
#       r2: 0.9869592036507464
# Ridge:
#       rmse: 47663.6746121074
#       r2: 0.9866880650848302
# Lasso:
#       rmse: 47228.6143208746
#       r2: 0.9869263583894006

# %%
list_sum
# Out:
# [(71171.28433534442, 71139.71315023475, 70683.01087271537),
#  (1701.3519532257749, 5365.528984532319, 3906.349954038211),
#  (68599.11963323943, 68675.20684710781, 69290.8378684582),
#  (47453.4503480798, 47793.650772502246, 47833.698846455874),
#  (1545.3999201624943, 3001.228101804623, 4654.27733073689),
#  (47160.81484295411, 47663.6746121074, 47228.6143208746)]

# %%
summary_table = pd.DataFrame(list_sum, columns = ['Linear_regression RMSE' , 'Ridge RMSE', 'Lasso RMSE'], index=['3 day ago with out total yield',
'3 day ago with total yield',
'3 day ago and today with out total yield',
'7 day ago with out total yield',
'7 day ago with total yield',
'7 day ago and today with out total yield'])

# %%
summary_table
# Out:
#                                           Linear_regression RMSE  ...    Lasso RMSE
# 3 day ago with out total yield                      71171.284335  ...  70683.010873
# 3 day ago with total yield                           1701.351953  ...   3906.349954
# 3 day ago and today with out total yield            68599.119633  ...  69290.837868
# 7 day ago with out total yield                      47453.450348  ...  47833.698846
# 7 day ago with total yield                           1545.399920  ...   4654.277331
# 7 day ago and today with out total yield            47160.814843  ...  47228.614321
#
# [6 rows x 3 columns]

# %% [markdown]
# # เปรียบเทียบความถูกต้อง

# %%
# เปรียบเทียบความถูกต้อง
#    o โดยลองทั้งการนําข้อมูลเฉพาะ 7 วันก่อนหน้าทุกคอลัมน์รวมทั้งคอลัมน์TOTAL_YIELD ของ ของ 3 วันนั้น

x_data = data_process.drop(['DATE_TIME','DC_POWER',	'AC_POWER',	'DAILY_YIELD',	'AMBIENT_TEMPERATURE',	'MODULE_TEMPERATURE'	,'IRRADIATION','TOTAL_YIELD'],axis = 1)
min_max_scaler = preprocessing.MinMaxScaler()
x = x_data.values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
x_normalize = pd.DataFrame(x_scaled,columns=x_data.columns)
y_data = data_process['TOTAL_YIELD']

list_fold_input, list_fold_label = get_ten_Fold(x_normalize,y_data)

linear_regression = LinearRegression()
ridge = Ridge()
lasso = Lasso(tol=1e-2)

print("### process Linear regression ####")
linear_regression_rsme,linear_regression_r2 = train(list_fold_input, list_fold_label,linear_regression)
print()

print("### process Ridge ####")
ridge_rsme,ridge_r2 = train(list_fold_input, list_fold_label,ridge)
print()

print("### process Lasso ####")
lasso_rsme,lasso_r2 = train(list_fold_input, list_fold_label,lasso)
print()

print()
print()
print("###Sumary###")
print(f"Linear regression:")
print(f"      rmse: {linear_regression_rsme}")
print(f"      r2: {linear_regression_r2}")
print(f"Ridge:")
print(f"      rmse: {ridge_rsme}")
print(f"      r2: {ridge_r2}")
print(f"Lasso:")
print(f"      rmse: {lasso_rsme}")
print(f"      r2: {lasso_r2}")
# Out:
# ### process Linear regression ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 1669.920433073473
# R2 : 0.9999852498718841
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 1345.8086892439812
# R2 : 0.9999884394029535
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 1674.9701627376276
# R2 : 0.9999849012154234
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 1342.8854715476355
# R2 : 0.9999884388545498
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 1669.8550191953493
# R2 : 0.9999849954819416
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 1357.7352940172689
# R2 : 0.999988041637328
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 1670.183762118527
# R2 : 0.9999850322373778
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 1351.3118641674282
# R2 : 0.9999881494748593
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 1671.6411425398253
# R2 : 0.9999851881469312
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 1699.687362983828
# R2 : 0.9999813875393015
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 1545.3999201624943
# Average R2: 0.999985982386255
#
# ### process Ridge ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 3252.773803591057
# R2 : 0.9999440355857765
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 2628.2526896752256
# R2 : 0.9999559092138144
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 3254.9571415553182
# R2 : 0.9999429811586881
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 2618.224017162849
# R2 : 0.9999560522627648
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 3253.1210565120255
# R2 : 0.9999430537713699
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 2624.219224343669
# R2 : 0.9999553273484495
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 3256.2006757814497
# R2 : 0.9999431080660699
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 2626.149772929716
# R2 : 0.9999552425435082
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 3254.789768749348
# R2 : 0.9999438474896476
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 3243.5928677455695
# R2 : 0.9999322173761417
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 3001.228101804623
# Average R2: 0.9999471774816231
#
# ### process Lasso ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 4675.867384135673
# R2 : 0.9998843545352956
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 4660.960506484279
# R2 : 0.9998613357669602
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 4672.7438880268055
# R2 : 0.9998824908202303
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 4674.492566402961
# R2 : 0.9998599149267856
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 4659.800890159602
# R2 : 0.9998831579312036
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 4649.275949168565
# R2 : 0.9998597792928975
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 4678.601877717335
# R2 : 0.9998825479626926
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 4633.078573206197
# R2 : 0.9998606953069984
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 4652.009394685513
# R2 : 0.9998852891603938
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 4585.942277381979
# R2 : 0.9998645051243259
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 4654.27733073689
# Average R2: 0.9998724070827784
#
#
#
# ###Sumary###
# Linear regression:
#       rmse: 1545.3999201624943
#       r2: 0.999985982386255
# Ridge:
#       rmse: 3001.228101804623
#       r2: 0.9999471774816231
# Lasso:
#       rmse: 4654.27733073689
#       r2: 0.9998724070827784

# %%
# เปรียบเทียบความถูกต้อง
#    o โดยลองทั้งการนําข้อมูลเฉพาะ 7 วันก่อนหน้าทุกคอลัมน์รวมทั้งคอลัมน์TOTAL_YIELD ของ ของ 3 วันนั้น
#    o และลองรวมข้อมูลของวันปัจจุบันที่ไม่ใช้คอลัมน์TOTAL_YIELD เข้ากับข้อมูล 3 วัน ของ 7 วันก่อนหน้า
x_data = data_process.drop(['DATE_TIME','TOTAL_YIELD'],axis = 1)
min_max_scaler = preprocessing.MinMaxScaler()
x = x_data.values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
x_normalize = pd.DataFrame(x_scaled,columns=x_data.columns)
y_data = data_process['TOTAL_YIELD']

list_fold_input, list_fold_label = get_ten_Fold(x_normalize,y_data)

linear_regression = LinearRegression()
ridge = Ridge()
lasso = Lasso(tol=1e-2)

print("### process Linear regression ####")
linear_regression_rsme,linear_regression_r2 = train(list_fold_input, list_fold_label,linear_regression)
print()

print("### process Ridge ####")
ridge_rsme,ridge_r2 = train(list_fold_input, list_fold_label,ridge)
print()

print("### process Lasso ####")
lasso_rsme,lasso_r2 = train(list_fold_input, list_fold_label,lasso)
print()
list_sum.append((linear_regression_rsme,ridge_rsme,lasso_rsme))

print()
print()
print("###Sumary###")
print(f"Linear regression:")
print(f"      rmse: {linear_regression_rsme}")
print(f"      r2: {linear_regression_r2}")
print(f"Ridge:")
print(f"      rmse: {ridge_rsme}")
print(f"      r2: {ridge_r2}")
print(f"Lasso:")
print(f"      rmse: {lasso_rsme}")
print(f"      r2: {lasso_r2}")
# Out:
# ### process Linear regression ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 1639.443539651638
# R2 : 0.9999857833535098
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 1333.6743275222757
# R2 : 0.9999886469332724
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 1646.5213868466456
# R2 : 0.9999854097547861
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 1329.4842107621755
# R2 : 0.9999886684509682
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 1638.4065816181687
# R2 : 0.9999855553213108
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 1342.6994060454003
# R2 : 0.9999883050303511
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 1637.4060325454452
# R2 : 0.9999856139639257
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 1336.4095016273352
# R2 : 0.9999884094104721
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 1638.249154616168
# R2 : 0.9999857739871276
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 1663.3118909438133
# R2 : 0.9999821756752039
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 1520.5606032179064
# Average R2: 0.9999864341880927
#
# ### process Ridge ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 3554.8163293443636
# R2 : 0.9999331596726874
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 2666.1878187091884
# R2 : 0.9999546272515366
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 3556.2265314794067
# R2 : 0.9999319376916708
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 2651.2644838600504
# R2 : 0.999954936074252
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 3548.976382797257
# R2 : 0.9999322248111312
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 2657.9355956634745
# R2 : 0.9999541720519438
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 3556.728823614444
# R2 : 0.9999321218680547
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 2660.7671960020043
# R2 : 0.9999540547973289
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 3554.110909490028
# R2 : 0.9999330446561323
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 3532.585903333767
# R2 : 0.9999196009039508
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 3193.9599974293983
# Average R2: 0.9999399879778688
#
# ### process Lasso ####
# Fold #1---------------------------------------
# Root Mean Squared Error (RMSE): 6906.539797763452
# R2 : 0.9997476953397025
# Fold #2---------------------------------------
# Root Mean Squared Error (RMSE): 6501.210870815151
# R2 : 0.9997302247438767
# Fold #3---------------------------------------
# Root Mean Squared Error (RMSE): 6858.851262990244
# R2 : 0.9997468192926683
# Fold #4---------------------------------------
# Root Mean Squared Error (RMSE): 6477.436362796058
# R2 : 0.9997310142801367
# Fold #5---------------------------------------
# Root Mean Squared Error (RMSE): 6846.5294810774685
# R2 : 0.9997477649220738
# Fold #6---------------------------------------
# Root Mean Squared Error (RMSE): 6479.231375541817
# R2 : 0.9997276743910113
# Fold #7---------------------------------------
# Root Mean Squared Error (RMSE): 6840.599783900662
# R2 : 0.9997489173304469
# Fold #8---------------------------------------
# Root Mean Squared Error (RMSE): 6523.079898740862
# R2 : 0.9997238584154687
# Fold #9---------------------------------------
# Root Mean Squared Error (RMSE): 6832.5426642886505
# R2 : 0.9997525496931156
# Fold #10---------------------------------------
# Root Mean Squared Error (RMSE): 7569.778132355825
# R2 : 0.9996308252375767
# ++++++ Average +++++++
# Average Root Mean Squared Error (RMSE): 6783.579963027019
# Average R2: 0.9997287343646075
#
#
#
# ###Sumary###
# Linear regression:
#       rmse: 1520.5606032179064
#       r2: 0.9999864341880927
# Ridge:
#       rmse: 3193.9599974293983
#       r2: 0.9999399879778688
# Lasso:
#       rmse: 6783.579963027019
#       r2: 0.9997287343646075

# %%
summary_table = pd.DataFrame(list_sum, columns = ['Linear_regression RMSE' , 'Ridge RMSE', 'Lasso RMSE'], index=['3 day ago with out total yield',
'3 day ago with total yield',
'3 day ago and today with out total yield',
'7 day ago with out total yield',
'7 day ago with total yield',
'7 day ago and today with out total yield',
"7 day ago with total yield and today"])

# %%
summary_table
# Out:
#                                           Linear_regression RMSE  ...    Lasso RMSE
# 3 day ago with out total yield                      71171.284335  ...  70683.010873
# 3 day ago with total yield                           1701.351953  ...   3906.349954
# 3 day ago and today with out total yield            68599.119633  ...  69290.837868
# 7 day ago with out total yield                      47453.450348  ...  47833.698846
# 7 day ago with total yield                           1545.399920  ...   4654.277331
# 7 day ago and today with out total yield            47160.814843  ...  47228.614321
# 7 day ago with total yield and today                 1520.560603  ...   6783.579963
#
# [7 rows x 3 columns]

# %% [markdown]
# # จากการทดสอบสามารถสรุปได้ดังนี้
# - ใช้ model Linear_regression ให้ความแม่นยำมากกว่าตัว Ridge และ Lasso
#
# - หากมีการนำค่า Total Yield มาคำนวณด้วยจะทำให้การทำนายที่ได้มีความแม่นยำมากขึ้น
#
# - หากใช้ข้อมูล 3 วันของ 7 วันก่อนหน้ามาคำนวณจะทำให้ข้อมูลมีความแม่นยำมากขึ้นกว่าการนำข้อมูล 3 วันของ 3 วันก่อนหน้า จึงทำให้เกิดสมมุนิฐานว่าวันจันทร์ ถึง อาทิตย์อาจจะมีความสัมพันธ์กับข้อมูล เพราะหากเราใช้วันใกล้เคียงกับวันดังกล่าวมาทำนาย อาจจะทำให้ได้ความแม่นยำมากขึ้น
